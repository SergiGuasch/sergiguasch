# %% [markdown]
# ___
#
# <a href='http://www.pieriandata.com'> <img src='../Pierian_Data_Logo.png' /></a>
# ___

# %% [markdown]
# # Finance Data Project
#
# In this data project we will focus on exploratory data analysis of stock prices. Keep in mind, this project is just meant to practice your visualization and pandas skills, it is not meant to be a robust financial analysis or be taken as financial advice.
# ____
# ** NOTE: This project is extremely challenging because it will introduce a lot of new concepts and have you looking things up on your own (we'll point you in the right direction) to try to solve the tasks issued. Feel free to just go through the solutions lecture notebook and video as a "walkthrough" project if you don't want to have to look things up yourself. You'll still learn a lot that way! **
# ____
# We'll focus on bank stocks and see how they progressed throughout the [financial crisis](https://en.wikipedia.org/wiki/Financial_crisis_of_2007%E2%80%9308) all the way to early 2016.

# %% [markdown]
# ## Get the Data
#
# In this section we will learn how to use pandas to directly read data from Google finance using pandas!
#
# First we need to start with the proper imports, which we've already laid out for you here.
#
# *Note: [You'll need to install pandas-datareader for this to work!](https://github.com/pydata/pandas-datareader) Pandas datareader allows you to [read stock information directly from the internet](http://pandas.pydata.org/pandas-docs/stable/remote_data.html) Use these links for install guidance (**pip install pandas-datareader**), or just follow along with the video lecture.*
#
# ### The Imports
#
# Already filled out for you.

# %%
import pandas as pd
import numpy as np
# %matplotlib inline
import warnings
warnings.filterwarnings('ignore')

# %% [markdown]
# ## Data
#
# We need to get data using pandas datareader. We will get stock information for the following banks:
# *  Bank of America
# * CitiGroup
# * Goldman Sachs
# * JPMorgan Chase
# * Morgan Stanley
# * Wells Fargo
#
# ** Figure out how to get the stock data from Jan 1st 2006 to Jan 1st 2016 for each of these banks. Set each bank to be a separate dataframe, with the variable name for that bank being its ticker symbol. This will involve a few steps:**
# 1. Use datetime to set start and end datetime objects.
# 2. Figure out the ticker symbol for each bank.
# 2. Figure out how to use datareader to grab info on the stock.
#
# ** Use [this documentation page](https://pandas-datareader.readthedocs.io/en/latest/remote_data.html) for hints and instructions (it should just be a matter of replacing certain values. Use google finance as a source, for example:**
#
#     # Bank of America
#     BAC = data.DataReader("BAC", 'google', start, end)
#
# ### WARNING: MAKE SURE TO CHECK THE LINK ABOVE FOR THE LATEST WORKING API. "google" MAY NOT ALWAYS WORK.
# ------------
# ### We also provide pickle file in the article lecture right before the video lectures.

# %%
import datetime
start = datetime.datetime(2008, 1, 1)
end = datetime.datetime(2023, 1, 1)

# %%
bank_tickers = {
    'Bank of America': 'BAC',
    'CitiGroup': 'C',
    'Goldman Sachs': 'GS',
    'JPMorgan Chase': 'JPM',
    'Morgan Stanley': 'MS',
    'Wells Fargo': 'WFC'
}

# %%
import pandas_datareader as pdr
import pandas_datareader.data as web

# %%
bank_data = {}

# use a for loop to get the data for each bank
for bank, ticker in bank_tickers.items():
    data = web.DataReader(ticker, 'iex', start=start, end=end, api_key='pk_dd238c7ca4a943bbb98d5dd437dae190')
    bank_data[ticker] = data

# %%
df2 = pd.concat(bank_data.values(), keys=bank_data.keys())
df2 = df2.unstack(level=0)
df2.columns = df2.columns.set_names(["Stock Info", "Bank Ticker"])
df2.columns = df2.columns.swaplevel(0, 1)
df2 = df2.sort_index(level=0, axis=1)
df2.columns = df2.columns.set_levels([level.capitalize() for level in df2.columns.levels[1]], level=1)
df2 = df2.sort_index(level=0, axis=1)
df2 = df2.reindex(columns=['Open','High','Low','Close','Volume'], level=1)
df2
# Out:
# Bank Ticker    BAC                                         C          \
# Stock Info    Open   High     Low  Close      Volume    Open    High
# date
# 2008-01-02   41.53  41.55  40.350  40.56  30767876.0  297.00  298.90
# 2008-01-03   40.63  40.81  40.250  40.30  22589488.0  292.20  293.90
# 2008-01-04   40.00  40.29  39.760  39.85  34924119.0  286.00  290.30
# 2008-01-07   40.05  40.24  39.260  39.90  31885085.0  283.40  287.60
# 2008-01-08   40.18  40.21  38.280  38.41  42147262.0  284.60  287.00
# ...            ...    ...     ...    ...         ...     ...     ...
# 2022-12-23   32.40  32.58  32.190  32.47  21378584.0   44.00   44.36
# 2022-12-27   32.50  32.67  32.275  32.53  22776092.0   44.28   44.54
# 2022-12-28   32.57  32.97  32.535  32.77  30541004.0   44.43   44.87
# 2022-12-29   32.89  33.16  32.750  33.14  22252908.0   44.84   45.24
# 2022-12-30   33.10  33.30  32.860  33.12  28198915.0   44.93   45.28
#
# ...

# %%
df2.loc[:, df2.columns.get_level_values(1) == 'Volume'] = df2.iloc[:, df2.columns.get_level_values(1) == 'Volume'].fillna(0).astype(np.int64)
df2=df2.fillna(0)
df2.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Index: 3788 entries, 2008-01-02 to 2022-12-30
# Data columns (total 30 columns):
#  #   Column         Non-Null Count  Dtype
# ---  ------         --------------  -----
#  0   (BAC, Open)    3788 non-null   float64
#  1   (BAC, High)    3788 non-null   float64
#  2   (BAC, Low)     3788 non-null   float64
#  3   (BAC, Close)   3788 non-null   float64
#  4   (BAC, Volume)  3788 non-null   int64
#  5   (C, Open)      3788 non-null   float64
#  6   (C, High)      3788 non-null   float64
#  7   (C, Low)       3788 non-null   float64
#  8   (C, Close)     3788 non-null   float64
#  9   (C, Volume)    3788 non-null   int64
#  10  (GS, Open)     3788 non-null   float64
#  11  (GS, High)     3788 non-null   float64
#  12  (GS, Low)      3788 non-null   float64
#  13  (GS, Close)    3788 non-null   float64
#  14  (GS, Volume)   3788 non-null   int64
#  15  (JPM, Open)    3788 non-null   float64
#  16  (JPM, High)    3788 non-null   float64
# ...

# %% [markdown]
# ----------------------------------------------------------------------------------------------------

# %%
df = pd.read_pickle('all_banks')

# %%
df
# Out:
# Bank Ticker    BAC                                      C                  \
# Stock Info    Open   High    Low  Close    Volume    Open    High     Low
# Date
# 2006-01-03   46.92  47.18  46.15  47.08  16296700  490.00  493.80  481.10
# 2006-01-04   47.00  47.24  46.45  46.58  17757900  488.60  491.00  483.50
# 2006-01-05   46.58  46.83  46.32  46.64  14970900  484.40  487.80  484.00
# 2006-01-06   46.80  46.91  46.35  46.57  12599800  488.80  489.00  482.00
# 2006-01-09   46.72  46.97  46.36  46.60  15620000  486.00  487.40  483.00
# ...            ...    ...    ...    ...       ...     ...     ...     ...
# 2015-12-24   17.32  17.38  17.22  17.27  29373415   52.48   52.97   52.45
# 2015-12-28   17.22  17.23  16.98  17.13  41777497   52.57   52.57   51.96
# 2015-12-29   17.25  17.35  17.16  17.28  45670376   52.76   53.22   52.74
# 2015-12-30   17.20  17.24  17.04  17.05  35066378   52.84   52.94   52.25
# 2015-12-31   17.01  17.07  16.83  16.83  47152968   52.07   52.39   51.75
#
# ...

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# DatetimeIndex: 2517 entries, 2006-01-03 to 2015-12-31
# Data columns (total 30 columns):
#  #   Column         Non-Null Count  Dtype
# ---  ------         --------------  -----
#  0   (BAC, Open)    2517 non-null   float64
#  1   (BAC, High)    2517 non-null   float64
#  2   (BAC, Low)     2517 non-null   float64
#  3   (BAC, Close)   2517 non-null   float64
#  4   (BAC, Volume)  2517 non-null   int64
#  5   (C, Open)      2517 non-null   float64
#  6   (C, High)      2517 non-null   float64
#  7   (C, Low)       2517 non-null   float64
#  8   (C, Close)     2517 non-null   float64
#  9   (C, Volume)    2517 non-null   int64
#  10  (GS, Open)     2517 non-null   float64
#  11  (GS, High)     2517 non-null   float64
#  12  (GS, Low)      2517 non-null   float64
#  13  (GS, Close)    2517 non-null   float64
#  14  (GS, Volume)   2517 non-null   int64
#  15  (JPM, Open)    2517 non-null   float64
#  16  (JPM, High)    2517 non-null   float64
# ...

# %% [markdown]
# ** Create a list of the ticker symbols (as strings) in alphabetical order. Call this list: tickers**

# %%
tickers = sorted(df.columns.get_level_values(0).unique())
tickers
# Out:
# ['BAC', 'C', 'GS', 'JPM', 'MS', 'WFC']

# %%
tickers2 = sorted(df2.columns.get_level_values(0).unique())
tickers2
# Out:
# ['BAC', 'C', 'GS', 'JPM', 'MS', 'WFC']

# %% [markdown]
# ** Use pd.concat to concatenate the bank dataframes together to a single data frame called bank_stocks. Set the keys argument equal to the tickers list. Also pay attention to what axis you concatenate on.**

# %%
bank_stocks = pd.concat([df['BAC'], df['C'], df['GS'], df['JPM'], df['MS'], df['WFC']], keys=tickers, axis=1)

# %%
bank_stocks2 = pd.concat([df2['BAC'], df2['C'], df2['GS'], df2['JPM'], df2['MS'], df2['WFC']], keys=tickers2, axis=1)

# %% [markdown]
# ** Set the column name levels (this is filled out for you):**

# %%
bank_stocks.columns.names = ['Bank Ticker','Stock Info']

# %%
bank_stocks2.columns.names = ['Bank Ticker','Stock Info']

# %% [markdown]
# ** Check the head of the bank_stocks dataframe.**

# %%
bank_stocks.head()
# Out:
# Bank Ticker    BAC                                     C                       \
# Stock Info    Open   High    Low  Close    Volume   Open   High    Low  Close
# Date
# 2006-01-03   46.92  47.18  46.15  47.08  16296700  490.0  493.8  481.1  492.9
# 2006-01-04   47.00  47.24  46.45  46.58  17757900  488.6  491.0  483.5  483.8
# 2006-01-05   46.58  46.83  46.32  46.64  14970900  484.4  487.8  484.0  486.2
# 2006-01-06   46.80  46.91  46.35  46.57  12599800  488.8  489.0  482.0  486.2
# 2006-01-09   46.72  46.97  46.36  46.60  15620000  486.0  487.4  483.0  483.9
#
# Bank Ticker           ...     MS                                  WFC         \
# Stock Info    Volume  ...   Open   High    Low  Close   Volume   Open   High
# Date                  ...
# 2006-01-03   1537660  ...  57.17  58.49  56.74  58.31  5377000  31.60  31.98
# 2006-01-04   1871020  ...  58.70  59.28  58.35  58.35  7977800  31.80  31.82
# 2006-01-05   1143160  ...  58.55  58.59  58.02  58.51  5778000  31.50  31.56
# ...

# %%
bank_stocks2.head()
# Out:
# Bank Ticker    BAC                                     C                       \
# Stock Info    Open   High    Low  Close    Volume   Open   High    Low  Close
# date
# 2008-01-02   41.53  41.55  40.35  40.56  30767876  297.0  298.9  288.5  289.2
# 2008-01-03   40.63  40.81  40.25  40.30  22589488  292.2  293.9  288.9  289.3
# 2008-01-04   40.00  40.29  39.76  39.85  34924119  286.0  290.3  280.4  282.4
# 2008-01-07   40.05  40.24  39.26  39.90  31885085  283.4  287.6  279.3  282.6
# 2008-01-08   40.18  40.21  38.28  38.41  42147262  284.6  287.0  270.1  271.4
#
# Bank Ticker           ...     MS                                   WFC         \
# Stock Info    Volume  ...   Open   High    Low  Close    Volume   Open   High
# date                  ...
# 2008-01-02   6214640  ...  52.96  53.40  50.31  50.95  17625056  30.48  30.48
# 2008-01-03   5965786  ...  51.21  51.89  50.58  50.94  11422184  29.25  29.37
# ...

# %% [markdown]
# # EDA
#
# Let's explore the data a bit! Before continuing, I encourage you to check out the documentation on [Multi-Level Indexing](http://pandas.pydata.org/pandas-docs/stable/advanced.html) and [Using .xs](http://pandas.pydata.org/pandas-docs/stable/generated/pandas.DataFrame.xs.html).
# Reference the solutions if you can not figure out how to use .xs(), since that will be a major part of this project.
#
# ** What is the max Close price for each bank's stock throughout the time period?**

# %%
df.iloc[:, df.columns.get_level_values(1) == 'Close'].max()
# Out:
# Bank Ticker  Stock Info
# BAC          Close          54.90
# C            Close         564.10
# GS           Close         247.92
# JPM          Close          70.08
# MS           Close          89.30
# WFC          Close          58.52
# dtype: float64

# %%
df.xs(key='Close', axis=1, level=1).max()
# Out:
# Bank Ticker
# BAC     54.90
# C      564.10
# GS     247.92
# JPM     70.08
# MS      89.30
# WFC     58.52
# dtype: float64

# %%
for tick in tickers:
    print(tick, bank_stocks[tick]['Close'].max())
# Out:
# BAC 54.9
# C 564.1
# GS 247.92
# JPM 70.08
# MS 89.3
# WFC 58.52

# %%
# Out:
# Bank Ticker
# BAC     54.90
# C      564.10
# GS     247.92
# JPM     70.08
# MS      89.30
# WFC     58.52
# dtype: float64

# %% [markdown]
# ** Create a new empty DataFrame called returns. This dataframe will contain the returns for each bank's stock. returns are typically defined by:**
#
# $$r_t = \frac{p_t - p_{t-1}}{p_{t-1}} = \frac{p_t}{p_{t-1}} - 1$$

# %%
returns = pd.DataFrame()

# %% [markdown]
# ** We can use pandas pct_change() method on the Close column to create a column representing this return value. Create a for loop that goes and for each Bank Stock Ticker creates this returns column and set's it as a column in the returns DataFrame.**

# %%
returns = df.xs(key='Close', axis=1, level=1).pct_change()
returns.head()
# Out:
# Bank Ticker       BAC         C        GS       JPM        MS       WFC
# Date
# 2006-01-03        NaN       NaN       NaN       NaN       NaN       NaN
# 2006-01-04  -0.010620 -0.018462 -0.013812 -0.014183  0.000686 -0.011599
# 2006-01-05   0.001288  0.004961 -0.000393  0.003029  0.002742 -0.000951
# 2006-01-06  -0.001501  0.000000  0.014169  0.007046  0.001025  0.005714
# 2006-01-09   0.000644 -0.004731  0.012030  0.016242  0.010586  0.000000

# %%
# Out:
#             BAC Return  C Return  GS Return  JPM Return  MS Return  WFC Return
# Date
# 2006-01-03         NaN       NaN        NaN         NaN        NaN         NaN
# 2006-01-04   -0.010620 -0.018462  -0.013812   -0.014183   0.000686   -0.011599
# 2006-01-05    0.001288  0.004961  -0.000393    0.003029   0.002742   -0.000951
# 2006-01-06   -0.001501  0.000000   0.014169    0.007046   0.001025    0.005714
# 2006-01-09    0.000644 -0.004731   0.012030    0.016242   0.010586    0.000000

# %% [markdown]
# ** Create a pairplot using seaborn of the returns dataframe. What stock stands out to you? Can you figure out why?**

# %%
import seaborn as sns
sns.pairplot(returns[1:])

# %% [markdown]
# * See solution for details about Citigroup behavior....

# %% [markdown]
# ** Using this returns DataFrame, figure out on what dates each bank stock had the best and worst single day returns. You should notice that 4 of the banks share the same day for the worst drop, did anything significant happen that day?**

# %%
worst_returns = returns.idxmin()
worst_returns
# Out:
# Bank Ticker
# BAC   2009-01-20
# C     2011-05-06
# GS    2009-01-20
# JPM   2009-01-20
# MS    2008-10-09
# WFC   2009-01-20
# dtype: datetime64[ns]

# %% [markdown]
# ** You should have noticed that Citigroup's largest drop and biggest gain were very close to one another, did anythign significant happen in that time frame? **

# %% [markdown]
# * See Solution for details

# %%
best_returns = returns.idxmax()
best_returns
# Out:
# Bank Ticker
# BAC   2009-04-09
# C     2011-05-09
# GS    2008-11-24
# JPM   2009-01-21
# MS    2008-10-13
# WFC   2008-07-16
# dtype: datetime64[ns]

# %% [markdown]
# ** Take a look at the standard deviation of the returns, which stock would you classify as the riskiest over the entire time period? Which would you classify as the riskiest for the year 2015?**

# %%
std_returns = returns.std()
std_returns
# Out:
# Bank Ticker
# BAC    0.036650
# C      0.179969
# GS     0.025346
# JPM    0.027656
# MS     0.037820
# WFC    0.030233
# dtype: float64

# %%
returns_2015 = returns[returns.index.year == 2015].std()
returns_2015
# Out:
# Bank Ticker
# BAC    0.016163
# C      0.015289
# GS     0.014046
# JPM    0.014017
# MS     0.016249
# WFC    0.012591
# dtype: float64

# %%
returns_2015_ix = returns.loc['2015-01-01':'2015-12-31'].std()
returns_2015_ix
# Out:
# Bank Ticker
# BAC    0.016163
# C      0.015289
# GS     0.014046
# JPM    0.014017
# MS     0.016249
# WFC    0.012591
# dtype: float64

# %% [markdown]
# ** Create a distplot using seaborn of the 2015 returns for Morgan Stanley **

# %%
sns.set_style('whitegrid')
returns_2015_MS = returns.loc[(returns.index.year == 2015),'MS']
sns.distplot(returns_2015_MS, bins=100, color='green')
# Out:
# <AxesSubplot: xlabel='MS', ylabel='Density'>

# %%
# Out:
# /Users/marci/anaconda/lib/python3.5/site-packages/statsmodels/nonparametric/kdetools.py:20: VisibleDeprecationWarning:
#
# using a non-integer number instead of an integer will result in an error in the future

# %% [markdown]
# ** Create a distplot using seaborn of the 2008 returns for CitiGroup **

# %%
returns_2008_C = returns.loc[(returns.index.year == 2008),'C']
sns.distplot(returns_2008_C, bins=100, color='red')
# Out:
# <AxesSubplot: xlabel='C', ylabel='Density'>

# %%
# Out:
# /Users/marci/anaconda/lib/python3.5/site-packages/statsmodels/nonparametric/kdetools.py:20: VisibleDeprecationWarning:
#
# using a non-integer number instead of an integer will result in an error in the future

# %% [markdown]
# ____
# # More Visualization
#
# A lot of this project will focus on visualizations. Feel free to use any of your preferred visualization libraries to try to recreate the described plots below, seaborn, matplotlib, plotly and cufflinks, or just pandas.
#
# ### Imports

# %%
import matplotlib.pyplot as plt
import seaborn as sns
sns.set_style('whitegrid')
# %matplotlib inline

# Optional Plotly Method Imports
import plotly
import cufflinks as cf
cf.go_offline()
# Out:
#         <script type="text/javascript">
#         window.PlotlyConfig = {MathJaxConfig: 'local'};
#         if (window.MathJax && window.MathJax.Hub && window.MathJax.Hub.Config) {window.MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}
#         if (typeof require !== 'undefined') {
#         require.undef("plotly");
#         requirejs.config({
#             paths: {
#                 'plotly': ['https://cdn.plot.ly/plotly-2.12.1.min']
#             }
#         });
#         require(['plotly'], function(Plotly) {
#             window._Plotly = Plotly;
#         });
#         }
#         </script>

# %% [markdown]
# ** Create a line plot showing Close price for each bank for the entire index of time. (Hint: Try using a for loop, or use [.xs](http://pandas.pydata.org/pandas-docs/stable/generated/pandas.DataFrame.xs.html) to get a cross section of the data.)**

# %%
plt.figure(figsize=(15,6))
for tick in tickers:
    df[tick]['Close'].plot(label=tick)

plt.legend()
plt.show()

# %%
plt.figure(figsize=(15,6))
df.xs(key='Close', axis=1, level=1).plot() #level=1 is the same than level='Stock Info'
plt.show()

# %%
df.xs(key='Close', axis=1, level=1).iplot()
# Out:
# <div>                            <div id="8315b59f-5719-411d-a595-1e74f54d808b" class="plotly-graph-div" style="height:525px; width:100%;"></div>            <script type="text/javascript">                require(["plotly"], function(Plotly) {                    window.PLOTLYENV=window.PLOTLYENV || {};
# ...

# %% [markdown]
# ## Moving Averages
#
# Let's analyze the moving averages for these stocks in the year 2008.
#
# ** Plot the rolling 30 day average against the Close Price for Bank Of America's stock for the year 2008**

# %%
plt.figure(figsize=(10,5))
df_2008_BAC = df.loc[(df.index.year == 2008),'BAC']
rolling_mean = df_2008_BAC['Close'].rolling(window=30, center=True).mean()
rolling_mean.plot(label='30 Day Avg', color='blue')
df_2008_BAC['Close'].plot(label='BAC CLOSE', color='green')
plt.legend()
plt.xlim(pd.to_datetime('2008-01-01'), pd.to_datetime('2008-12-31'))
plt.show()

# %% [markdown]
# ** Create a heatmap of the correlation between the stocks Close Price.**

# %%
df_close = df.xs(key='Close', axis=1, level=1)
df_corr = df_close.corr()
sns.heatmap(df_corr, annot=True, cmap=sns.color_palette("RdBu", as_cmap=True).reversed(), vmin=-0.8, vmax=0.8)
# Out:
# <AxesSubplot: xlabel='Bank Ticker', ylabel='Bank Ticker'>

# %% [markdown]
# ** Optional: Use seaborn's clustermap to cluster the correlations together:**

# %%
sns.clustermap(df_corr, annot=True, cmap=sns.color_palette("RdBu", as_cmap=True).reversed(), vmin=-1, vmax=1)

# %%
df_corr.iplot(kind='heatmap', colorscale='rdylbu')
# Out:
# <div>                            <div id="2d57a974-2be7-46a1-8fc6-bd1bb61d0a23" class="plotly-graph-div" style="height:525px; width:100%;"></div>            <script type="text/javascript">                require(["plotly"], function(Plotly) {                    window.PLOTLYENV=window.PLOTLYENV || {};
# ...

# %% [markdown]
# # Part 2 (Optional)
#
# In this second part of the project we will rely on the cufflinks library to create some Technical Analysis plots. This part of the project is experimental due to its heavy reliance on the cuffinks project, so feel free to skip it if any functionality is broken in the future.

# %% [markdown]
# ** Use .iplot(kind='candle) to create a candle plot of Bank of America's stock from Jan 1st 2015 to Jan 1st 2016.**

# %%
df_2015_BAC = df.loc[(df.index.year == 2015),'BAC']
df_2015_BAC.iplot(kind='candle')
# Out:
# <div>                            <div id="ce480595-76a0-4d04-8710-3f68eee9461b" class="plotly-graph-div" style="height:525px; width:100%;"></div>            <script type="text/javascript">                require(["plotly"], function(Plotly) {                    window.PLOTLYENV=window.PLOTLYENV || {};
# ...

# %% [markdown]
# ** Use .ta_plot(study='sma') to create a Simple Moving Averages plot of Morgan Stanley for the year 2015.**

# %%
df_2015_MS = df.loc[(df.index.year == 2015),'MS']['Close']
df_2015_MS.ta_plot(study='sma', periods=[13,21,25])
# Out:
# <div>                            <div id="af0b918e-5748-4f9c-8ca4-e3bd15579eab" class="plotly-graph-div" style="height:525px; width:100%;"></div>            <script type="text/javascript">                require(["plotly"], function(Plotly) {                    window.PLOTLYENV=window.PLOTLYENV || {};
# ...

# %% [markdown]
# **Use .ta_plot(study='boll') to create a Bollinger Band Plot for Bank of America for the year 2015.**

# %%
df_2015_BAC = df.loc[(df.index.year == 2015),'BAC']['Close']
df_2015_BAC.ta_plot(study='boll')
# Out:
# <div>                            <div id="4e959158-6c17-48bd-a83f-579335d22992" class="plotly-graph-div" style="height:525px; width:100%;"></div>            <script type="text/javascript">                require(["plotly"], function(Plotly) {                    window.PLOTLYENV=window.PLOTLYENV || {};
# ...

# %% [markdown]
# # Great Job!
#
# Definitely a lot of more specific finance topics here, so don't worry if you didn't understand them all! The only thing you should be concerned with understanding are the basic pandas and visualization oeprations.
