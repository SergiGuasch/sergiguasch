# %% [markdown]
# # Sergi Guasch

# %% [markdown]
# ## This notebook talks about my holidays preferences where it will shows some pictures and a youtube link.

# %% [markdown]
# ## Profile

# %%
name = str(input("Please enter your name: "))
# Out:
# Please enter a name: Sergi

# %% [markdown]
# ![Carnet.jpg](attachment:Carnet.jpg)

# %%
place = str(input("Please enter the name of the place of your holiday preferences: "))
# Out:
# Please enter the name of the place of your holiday preferences: Emporda

# %% [markdown]
# ## Place

# %% [markdown]
# ![Beach.jpg](attachment:Beach.jpg)

# %% [markdown]
# <font color='pink'>**The top 3 thing that you love to do are:**</font>
#
# - 1 *Swimming in the beach*
# - 2 *Have a dinner*
# - 3 *Go Hiking*

# %% [markdown]
# ## Youtube link

# %%
print('The next link is a video from youtube of the place of your holiday preference:')
print('https://www.youtube.com/watch?v=95VF8xAMHJw')
# Out:
# The next link is a video from youtube of the place of your holiday preference:
# https://www.youtube.com/watch?v=95VF8xAMHJw

# %%
#I've uised the input() function to ask for the user's name or place of holidays.
#I've uised the print() function to print text and a link.
