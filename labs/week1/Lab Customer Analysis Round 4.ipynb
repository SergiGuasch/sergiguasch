# %% [markdown]
# # Lab | Customer Analysis Round 4

# %% [markdown]
# ## Dealing with the data

# %%
import pandas as pd 
import numpy as np 
import matplotlib.pyplot as plt 
import seaborn as sns

# %%
ls
# Out:
#  Volume in drive C is OS
#  Volume Serial Number is A4B9-8E3D
#
#  Directory of C:\Users\Sergi\OneDrive\Documents\GitHub\sergiguasch\labs\week1
#
# 01/20/2022  07:26 PM    <DIR>          .
# 01/19/2022  02:01 PM    <DIR>          ..
# 01/20/2022  06:18 PM    <DIR>          .ipynb_checkpoints
# 01/19/2022  02:10 PM           175,631 Jupyter Notebook.ipynb
# 01/19/2022  02:23 PM           114,781 Lab Customer Analysis Round 1.ipynb
# 01/19/2022  07:21 PM           115,174 Lab Customer Analysis Round 2.ipynb
# 01/20/2022  06:15 PM           271,964 Lab Customer Analysis Round 3.ipynb
# 01/20/2022  07:26 PM         1,941,274 Lab Customer Analysis Round 4.ipynb
# 01/19/2022  02:13 PM         2,015,683 marketing_customer_analysis.csv
#                6 File(s)      4,634,507 bytes
#                3 Dir(s)  342,821,724,160 bytes free

# %% [markdown]
# ### Show the dataframe shape

# %%
mca=pd.read_csv('marketing_customer_analysis.csv')

# %%
mca.shape
# Out:
# (10910, 26)

# %% [markdown]
# ### Standardize header names

# %%
mca.head()
# Out:
#    Unnamed: 0 Customer       State  Customer Lifetime Value Response  \
# 0           0  DK49336     Arizona              4809.216960       No
# 1           1  KX64629  California              2228.525238       No
# 2           2  LZ68649  Washington             14947.917300       No
# 3           3  XL78013      Oregon             22332.439460      Yes
# 4           4  QA50777      Oregon              9025.067525       No
#
#    Coverage Education Effective To Date EmploymentStatus Gender  ...  \
# 0     Basic   College           2/18/11         Employed      M  ...
# 1     Basic   College           1/18/11       Unemployed      F  ...
# 2     Basic  Bachelor           2/10/11         Employed      M  ...
# 3  Extended   College           1/11/11         Employed      M  ...
# 4   Premium  Bachelor           1/17/11    Medical Leave      F  ...
#
#    Number of Open Complaints Number of Policies     Policy Type        Policy  \
# ...

# %%
mca.columns
# Out:
# Index(['Unnamed: 0', 'Customer', 'State', 'Customer Lifetime Value',
#        'Response', 'Coverage', 'Education', 'Effective To Date',
#        'EmploymentStatus', 'Gender', 'Income', 'Location Code',
#        'Marital Status', 'Monthly Premium Auto', 'Months Since Last Claim',
#        'Months Since Policy Inception', 'Number of Open Complaints',
#        'Number of Policies', 'Policy Type', 'Policy', 'Renew Offer Type',
#        'Sales Channel', 'Total Claim Amount', 'Vehicle Class', 'Vehicle Size',
#        'Vehicle Type'],
#       dtype='object')

# %%
cols=[]
for i in range(len(mca.columns)):
    cols.append(mca.columns[i].lower())

# %%
mca.columns = cols

# %%
mca.columns
# Out:
# Index(['unnamed: 0', 'customer', 'state', 'customer lifetime value',
#        'response', 'coverage', 'education', 'effective to date',
#        'employmentstatus', 'gender', 'income', 'location code',
#        'marital status', 'monthly premium auto', 'months since last claim',
#        'months since policy inception', 'number of open complaints',
#        'number of policies', 'policy type', 'policy', 'renew offer type',
#        'sales channel', 'total claim amount', 'vehicle class', 'vehicle size',
#        'vehicle type'],
#       dtype='object')

# %%
mca.columns=mca.columns.str.replace(" ", "_")

# %%
mca.columns
# Out:
# Index(['unnamed:_0', 'customer', 'state', 'customer_lifetime_value',
#        'response', 'coverage', 'education', 'effective_to_date',
#        'employmentstatus', 'gender', 'income', 'location_code',
#        'marital_status', 'monthly_premium_auto', 'months_since_last_claim',
#        'months_since_policy_inception', 'number_of_open_complaints',
#        'number_of_policies', 'policy_type', 'policy', 'renew_offer_type',
#        'sales_channel', 'total_claim_amount', 'vehicle_class', 'vehicle_size',
#        'vehicle_type'],
#       dtype='object')

# %%
new_names={'unnamed:_0':'id'}

# %%
mca.rename(columns=new_names,inplace=True)

# %%
mca.columns
# Out:
# Index(['id', 'customer', 'state', 'customer_lifetime_value', 'response',
#        'coverage', 'education', 'effective_to_date', 'employmentstatus',
#        'gender', 'income', 'location_code', 'marital_status',
#        'monthly_premium_auto', 'months_since_last_claim',
#        'months_since_policy_inception', 'number_of_open_complaints',
#        'number_of_policies', 'policy_type', 'policy', 'renew_offer_type',
#        'sales_channel', 'total_claim_amount', 'vehicle_class', 'vehicle_size',
#        'vehicle_type'],
#       dtype='object')

# %% [markdown]
# ### Which columns are numerical?

# %%
mca.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 10910 entries, 0 to 10909
# Data columns (total 26 columns):
#  #   Column                         Non-Null Count  Dtype
# ---  ------                         --------------  -----
#  0   id                             10910 non-null  int64
#  1   customer                       10910 non-null  object
#  2   state                          10279 non-null  object
#  3   customer_lifetime_value        10910 non-null  float64
#  4   response                       10279 non-null  object
#  5   coverage                       10910 non-null  object
#  6   education                      10910 non-null  object
#  7   effective_to_date              10910 non-null  object
#  8   employmentstatus               10910 non-null  object
#  9   gender                         10910 non-null  object
#  10  income                         10910 non-null  int64
#  11  location_code                  10910 non-null  object
# ...

# %%
mca.select_dtypes([np.number])
# Out:
#           id  customer_lifetime_value  income  monthly_premium_auto  \
# 0          0              4809.216960   48029                    61
# 1          1              2228.525238       0                    64
# 2          2             14947.917300   22139                   100
# 3          3             22332.439460   49078                    97
# 4          4              9025.067525   23675                   117
# ...      ...                      ...     ...                   ...
# 10905  10905             15563.369440       0                   253
# 10906  10906              5259.444853   61146                    65
# 10907  10907             23893.304100   39837                   201
# 10908  10908             11971.977650   64195                   158
# 10909  10909              6857.519928       0                   101
#
#        months_since_last_claim  months_since_policy_inception  \
# 0                          7.0                             52
# ...

# %% [markdown]
# ### Which columns are categorical?

# %%
mca.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 10910 entries, 0 to 10909
# Data columns (total 26 columns):
#  #   Column                         Non-Null Count  Dtype
# ---  ------                         --------------  -----
#  0   id                             10910 non-null  int64
#  1   customer                       10910 non-null  object
#  2   state                          10279 non-null  object
#  3   customer_lifetime_value        10910 non-null  float64
#  4   response                       10279 non-null  object
#  5   coverage                       10910 non-null  object
#  6   education                      10910 non-null  object
#  7   effective_to_date              10910 non-null  object
#  8   employmentstatus               10910 non-null  object
#  9   gender                         10910 non-null  object
#  10  income                         10910 non-null  int64
#  11  location_code                  10910 non-null  object
# ...

# %%
mca.select_dtypes([object])
# Out:
#       customer       state response  coverage education effective_to_date  \
# 0      DK49336     Arizona       No     Basic   College           2/18/11
# 1      KX64629  California       No     Basic   College           1/18/11
# 2      LZ68649  Washington       No     Basic  Bachelor           2/10/11
# 3      XL78013      Oregon      Yes  Extended   College           1/11/11
# 4      QA50777      Oregon       No   Premium  Bachelor           1/17/11
# ...        ...         ...      ...       ...       ...               ...
# 10905  FE99816      Nevada       No   Premium  Bachelor           1/19/11
# 10906  KX53892      Oregon       No     Basic   College            1/6/11
# 10907  TL39050     Arizona       No  Extended  Bachelor            2/6/11
# 10908  WA60547  California       No   Premium   College           2/13/11
# 10909  IV32877         NaN      NaN     Basic  Bachelor            1/8/11
#
#       employmentstatus gender location_code marital_status     policy_type  \
# ...

# %% [markdown]
# ### Check and deal with NaN values

# %%
nulls_df=pd.DataFrame(round(mca.isna().sum()/len(mca),4)*100)

# %%
nulls_df=nulls_df.rename(columns={'index':'header',0:'prop_nulls'})

# %%
nulls_df
# Out:
#                                prop_nulls
# id                                   0.00
# customer                             0.00
# state                                5.78
# customer_lifetime_value              0.00
# response                             5.78
# coverage                             0.00
# education                            0.00
# effective_to_date                    0.00
# employmentstatus                     0.00
# gender                               0.00
# income                               0.00
# location_code                        0.00
# marital_status                       0.00
# monthly_premium_auto                 0.00
# months_since_last_claim              5.80
# months_since_policy_inception        0.00
# number_of_open_complaints            5.80
# number_of_policies                   0.00
# policy_type                          0.00
# policy                               0.00
# renew_offer_type                     0.00
# ...

# %%
mca['state']=mca['state'].fillna("Unknown")

# %%
nulls_df2=pd.DataFrame(round(mca.isna().sum()/len(mca),4)*100)

# %%
nulls_df2
# Out:
#                                    0
# id                              0.00
# customer                        0.00
# state                           0.00
# customer_lifetime_value         0.00
# response                        5.78
# coverage                        0.00
# education                       0.00
# effective_to_date               0.00
# employmentstatus                0.00
# gender                          0.00
# income                          0.00
# location_code                   0.00
# marital_status                  0.00
# monthly_premium_auto            0.00
# months_since_last_claim         5.80
# months_since_policy_inception   0.00
# number_of_open_complaints       5.80
# number_of_policies              0.00
# policy_type                     0.00
# policy                          0.00
# renew_offer_type                0.00
# sales_channel                   0.00
# total_claim_amount              0.00
# vehicle_class                   5.70
# ...

# %%
mca['response']=mca['response'].fillna("Unknown")
mca['vehicle_class']=mca['vehicle_class'].fillna("Unknown")
mca['vehicle_size']=mca['vehicle_size'].fillna("Unknown")

# %%
nulls_df3=pd.DataFrame(round(mca.isna().sum()/len(mca),4)*100)

# %%
nulls_df3
# Out:
#                                    0
# id                              0.00
# customer                        0.00
# state                           0.00
# customer_lifetime_value         0.00
# response                        0.00
# coverage                        0.00
# education                       0.00
# effective_to_date               0.00
# employmentstatus                0.00
# gender                          0.00
# income                          0.00
# location_code                   0.00
# marital_status                  0.00
# monthly_premium_auto            0.00
# months_since_last_claim         5.80
# months_since_policy_inception   0.00
# number_of_open_complaints       5.80
# number_of_policies              0.00
# policy_type                     0.00
# policy                          0.00
# renew_offer_type                0.00
# sales_channel                   0.00
# total_claim_amount              0.00
# vehicle_class                   0.00
# ...

# %%
mca=mca.drop(['vehicle_type'],axis=1)

# %%
nulls_df4=pd.DataFrame(round(mca.isna().sum()/len(mca),4)*100)

# %%
nulls_df4
# Out:
#                                  0
# id                             0.0
# customer                       0.0
# state                          0.0
# customer_lifetime_value        0.0
# response                       0.0
# coverage                       0.0
# education                      0.0
# effective_to_date              0.0
# employmentstatus               0.0
# gender                         0.0
# income                         0.0
# location_code                  0.0
# marital_status                 0.0
# monthly_premium_auto           0.0
# months_since_last_claim        5.8
# months_since_policy_inception  0.0
# number_of_open_complaints      5.8
# number_of_policies             0.0
# policy_type                    0.0
# policy                         0.0
# renew_offer_type               0.0
# sales_channel                  0.0
# total_claim_amount             0.0
# vehicle_class                  0.0
# vehicle_size                   0.0

# %%
import statistics as stats

# %%
med_1=mca['months_since_last_claim'].median()
med_2=mca['number_of_open_complaints'].median()

# %%
mca['months_since_last_claim']=mca['months_since_last_claim'].fillna(med_1)
mca['number_of_open_complaints']=mca['number_of_open_complaints'].fillna(med_2)

# %%
nulls_df5=pd.DataFrame(round(mca.isna().sum()/len(mca),4)*100)

# %%
nulls_df5
# Out:
#                                  0
# id                             0.0
# customer                       0.0
# state                          0.0
# customer_lifetime_value        0.0
# response                       0.0
# coverage                       0.0
# education                      0.0
# effective_to_date              0.0
# employmentstatus               0.0
# gender                         0.0
# income                         0.0
# location_code                  0.0
# marital_status                 0.0
# monthly_premium_auto           0.0
# months_since_last_claim        0.0
# months_since_policy_inception  0.0
# number_of_open_complaints      0.0
# number_of_policies             0.0
# policy_type                    0.0
# policy                         0.0
# renew_offer_type               0.0
# sales_channel                  0.0
# total_claim_amount             0.0
# vehicle_class                  0.0
# vehicle_size                   0.0

# %%
#print(med_1, med_2) -- not working?

# %% [markdown]
# ### Datetime format
# - Extract the months from the dataset and store in a separate column. Then filter the data to show only the information for the first quarter , ie. January, February and March. Hint: If data from March does not exist, consider only January and February.

# %%
import time 
from datetime import date

# %%
mca.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 10910 entries, 0 to 10909
# Data columns (total 25 columns):
#  #   Column                         Non-Null Count  Dtype
# ---  ------                         --------------  -----
#  0   id                             10910 non-null  int64
#  1   customer                       10910 non-null  object
#  2   state                          10910 non-null  object
#  3   customer_lifetime_value        10910 non-null  float64
#  4   response                       10910 non-null  object
#  5   coverage                       10910 non-null  object
#  6   education                      10910 non-null  object
#  7   effective_to_date              10910 non-null  object
#  8   employmentstatus               10910 non-null  object
#  9   gender                         10910 non-null  object
#  10  income                         10910 non-null  int64
#  11  location_code                  10910 non-null  object
# ...

# %%
mca['effective_to_date']=pd.to_datetime(mca['effective_to_date'],errors='coerce')
mca.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 10910 entries, 0 to 10909
# Data columns (total 25 columns):
#  #   Column                         Non-Null Count  Dtype
# ---  ------                         --------------  -----
#  0   id                             10910 non-null  int64
#  1   customer                       10910 non-null  object
#  2   state                          10910 non-null  object
#  3   customer_lifetime_value        10910 non-null  float64
#  4   response                       10910 non-null  object
#  5   coverage                       10910 non-null  object
#  6   education                      10910 non-null  object
#  7   effective_to_date              10910 non-null  datetime64[ns]
#  8   employmentstatus               10910 non-null  object
#  9   gender                         10910 non-null  object
#  10  income                         10910 non-null  int64
#  11  location_code                  10910 non-null  object
# ...

# %%
#mca['month']=mca['effective_to_date'].mca.month
#mca['month']=mca['effective_to_date'].mca.strftime('%b')
mca['month']=pd.DatetimeIndex(mca['effective_to_date']).month

# %%
mca
# Out:
#           id customer       state  customer_lifetime_value response  coverage  \
# 0          0  DK49336     Arizona              4809.216960       No     Basic
# 1          1  KX64629  California              2228.525238       No     Basic
# 2          2  LZ68649  Washington             14947.917300       No     Basic
# 3          3  XL78013      Oregon             22332.439460      Yes  Extended
# 4          4  QA50777      Oregon              9025.067525       No   Premium
# ...      ...      ...         ...                      ...      ...       ...
# 10905  10905  FE99816      Nevada             15563.369440       No   Premium
# 10906  10906  KX53892      Oregon              5259.444853       No     Basic
# 10907  10907  TL39050     Arizona             23893.304100       No  Extended
# 10908  10908  WA60547  California             11971.977650       No   Premium
# 10909  10909  IV32877     Unknown              6857.519928  Unknown     Basic
#
# ...

# %%
quarter_year = [1,2,3]
mca_months = mca[mca.month.isin(quarter_year)]

# %%
mca_months
# Out:
#           id customer       state  customer_lifetime_value response  coverage  \
# 0          0  DK49336     Arizona              4809.216960       No     Basic
# 1          1  KX64629  California              2228.525238       No     Basic
# 2          2  LZ68649  Washington             14947.917300       No     Basic
# 3          3  XL78013      Oregon             22332.439460      Yes  Extended
# 4          4  QA50777      Oregon              9025.067525       No   Premium
# ...      ...      ...         ...                      ...      ...       ...
# 10905  10905  FE99816      Nevada             15563.369440       No   Premium
# 10906  10906  KX53892      Oregon              5259.444853       No     Basic
# 10907  10907  TL39050     Arizona             23893.304100       No  Extended
# 10908  10908  WA60547  California             11971.977650       No   Premium
# 10909  10909  IV32877     Unknown              6857.519928  Unknown     Basic
#
# ...

# %% [markdown]
# ### BONUS: Put all the previously mentioned data transformations into a function.

# %%
mca.head(0)
# Out:
# Empty DataFrame
# Columns: [id, customer, state, customer_lifetime_value, response, coverage, education, effective_to_date, employmentstatus, gender, income, location_code, marital_status, monthly_premium_auto, months_since_last_claim, months_since_policy_inception, number_of_open_complaints, number_of_policies, policy_type, policy, renew_offer_type, sales_channel, total_claim_amount, vehicle_class, vehicle_size, month]
# Index: []
#
# [0 rows x 26 columns]

# %%
def standardize_header (mca):
    cols=[]
    for i in range(len(mca.columns)):
        cols.append(mca.columns[i].lower())
    mca.columns = cols
    mca.columns=mca.columns.str.replace(" ", "_")
    
standardize_header(mca)

# %%
mca.head(0)
# Out:
# Empty DataFrame
# Columns: [id, customer, state, customer_lifetime_value, response, coverage, education, effective_to_date, employmentstatus, gender, income, location_code, marital_status, monthly_premium_auto, months_since_last_claim, months_since_policy_inception, number_of_open_complaints, number_of_policies, policy_type, policy, renew_offer_type, sales_channel, total_claim_amount, vehicle_class, vehicle_size, month]
# Index: []
#
# [0 rows x 26 columns]

# %% [markdown]
# ## Show DataFrame info.

# %%
mca.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 10910 entries, 0 to 10909
# Data columns (total 26 columns):
#  #   Column                         Non-Null Count  Dtype
# ---  ------                         --------------  -----
#  0   id                             10910 non-null  int64
#  1   customer                       10910 non-null  object
#  2   state                          10910 non-null  object
#  3   customer_lifetime_value        10910 non-null  float64
#  4   response                       10910 non-null  object
#  5   coverage                       10910 non-null  object
#  6   education                      10910 non-null  object
#  7   effective_to_date              10910 non-null  datetime64[ns]
#  8   employmentstatus               10910 non-null  object
#  9   gender                         10910 non-null  object
#  10  income                         10910 non-null  int64
#  11  location_code                  10910 non-null  object
# ...

# %% [markdown]
# ## Describe DataFrame.

# %%
mca.describe()
# Out:
#                  id  customer_lifetime_value        income  \
# count  10910.000000             10910.000000  10910.000000
# mean    5454.500000              8018.241094  37536.284785
# std     3149.590053              6885.081434  30359.195670
# min        0.000000              1898.007675      0.000000
# 25%     2727.250000              4014.453113      0.000000
# 50%     5454.500000              5771.147235  33813.500000
# 75%     8181.750000              8992.779137  62250.750000
# max    10909.000000             83325.381190  99981.000000
#
#        monthly_premium_auto  months_since_last_claim  \
# count          10910.000000             10910.000000
# mean              93.196059                15.082401
# std               34.442532                 9.787208
# min               61.000000                 0.000000
# 25%               68.000000                 7.000000
# 50%               83.000000                14.000000
# 75%              109.000000                23.000000
# ...

# %% [markdown]
# ## Show a plot of the total number of responses (for each response type - "Yes"/"No").

# %%
mca
# Out:
#           id customer       state  customer_lifetime_value response  coverage  \
# 0          0  DK49336     Arizona              4809.216960       No     Basic
# 1          1  KX64629  California              2228.525238       No     Basic
# 2          2  LZ68649  Washington             14947.917300       No     Basic
# 3          3  XL78013      Oregon             22332.439460      Yes  Extended
# 4          4  QA50777      Oregon              9025.067525       No   Premium
# ...      ...      ...         ...                      ...      ...       ...
# 10905  10905  FE99816      Nevada             15563.369440       No   Premium
# 10906  10906  KX53892      Oregon              5259.444853       No     Basic
# 10907  10907  TL39050     Arizona             23893.304100       No  Extended
# 10908  10908  WA60547  California             11971.977650       No   Premium
# 10909  10909  IV32877     Unknown              6857.519928  Unknown     Basic
#
# ...

# %%
import seaborn as sns 
import matplotlib.pyplot as plt 
# %matplotlib inline

# %%
res=mca.query('response==["Yes","No"]')

# %%
res['response'].value_counts().plot(kind='bar',color='blue')
# Out:
# <AxesSubplot:>

# %% [markdown]
# ## Show a plot of the rate of the response types by each Sales Channel.

# %%
mca['sales_channel'].value_counts().plot(kind='bar',color='blue')
# Out:
# <AxesSubplot:>

# %%
res=mca.query('response==["Yes","No"]')

# %%
res.groupby('sales_channel')['response'].value_counts().unstack().plot.bar(ylabel='Responses')
# Out:
# <AxesSubplot:xlabel='sales_channel', ylabel='Responses'>

# %% [markdown]
# ## Show a plot of the distribution of the Total Claim Amount, broken down by response type. Try a boxplot and distribution plot, for each response type. For the distribution plot, try to plot both kinds of responses in one chart (seaborn's histplot, using the 'hue' parameter is very convenient here).

# %%
#boxplot
sns.set(rc={"figure.figsize":(15, 15)})
sns.boxplot(x=res['response'], y='total_claim_amount', data=mca)
# Out:
# <AxesSubplot:xlabel='response', ylabel='total_claim_amount'>

# %%
# sns.set(rc={"figure.figsize":(15, 15)})
# sns.boxplot(x=res['response'], y='total_claim_amount', data=mca)
res.groupby('response')['total_claim_amount'].hist(bins=20, legend=True);

# %%
sns.displot(res, x="total_claim_amount", hue="response", multiple="stack")

# %% [markdown]
# ## Create similar plots like in the task before, but for Income.

# %%
#boxplot
sns.set(rc={"figure.figsize":(10, 10)})
sns.boxplot(x=res['response'], y='income', data=mca)
# Out:
# <AxesSubplot:xlabel='response', ylabel='income'>

# %%
#sns.set(rc={"figure.figsize":(15, 15)})
#sns.boxplot(x=res['response'], y='income', data=mca)
res.groupby('response')['income'].hist(bins=20, legend=True);

# %% [markdown]
# ## Create a scatterplot between Total Claim Amount and Income. Play around with the settings of the scatterplot (markersize, alpha level, ...) and in doing so try to identify more features within the data just visually. You can also try different seaborn plots. Check for example this link which explains how to avoid overplotting.

# %%
plt.scatter(x='income', y='total_claim_amount', data=mca, color='green', marker='+')

# %% [markdown]
# ## Check the data types of the columns. Get the numeric data into dataframe called numerical and categorical columns in a dataframe called categoricals. (You can use np.number and object to select the numerical data types and categorical data types respectively)

# %%
mca.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 10910 entries, 0 to 10909
# Data columns (total 26 columns):
#  #   Column                         Non-Null Count  Dtype
# ---  ------                         --------------  -----
#  0   id                             10910 non-null  int64
#  1   customer                       10910 non-null  object
#  2   state                          10910 non-null  object
#  3   customer_lifetime_value        10910 non-null  float64
#  4   response                       10910 non-null  object
#  5   coverage                       10910 non-null  object
#  6   education                      10910 non-null  object
#  7   effective_to_date              10910 non-null  datetime64[ns]
#  8   employmentstatus               10910 non-null  object
#  9   gender                         10910 non-null  object
#  10  income                         10910 non-null  int64
#  11  location_code                  10910 non-null  object
# ...

# %%
mca=mca.drop(columns=['id'])

# %%
categorical=mca.select_dtypes([object])
numerical=mca.select_dtypes([np.number])

# %%
categorical
# Out:
#       customer       state response  coverage education employmentstatus  \
# 0      DK49336     Arizona       No     Basic   College         Employed
# 1      KX64629  California       No     Basic   College       Unemployed
# 2      LZ68649  Washington       No     Basic  Bachelor         Employed
# 3      XL78013      Oregon      Yes  Extended   College         Employed
# 4      QA50777      Oregon       No   Premium  Bachelor    Medical Leave
# ...        ...         ...      ...       ...       ...              ...
# 10905  FE99816      Nevada       No   Premium  Bachelor       Unemployed
# 10906  KX53892      Oregon       No     Basic   College         Employed
# 10907  TL39050     Arizona       No  Extended  Bachelor         Employed
# 10908  WA60547  California       No   Premium   College         Employed
# 10909  IV32877     Unknown  Unknown     Basic  Bachelor       Unemployed
#
#       gender location_code marital_status     policy_type        policy  \
# ...

# %%
numerical
# Out:
#        customer_lifetime_value  income  monthly_premium_auto  \
# 0                  4809.216960   48029                    61
# 1                  2228.525238       0                    64
# 2                 14947.917300   22139                   100
# 3                 22332.439460   49078                    97
# 4                  9025.067525   23675                   117
# ...                        ...     ...                   ...
# 10905             15563.369440       0                   253
# 10906              5259.444853   61146                    65
# 10907             23893.304100   39837                   201
# 10908             11971.977650   64195                   158
# 10909              6857.519928       0                   101
#
#        months_since_last_claim  months_since_policy_inception  \
# 0                          7.0                             52
# 1                          3.0                             26
# ...

# %% [markdown]
# ## Now we will try to check the normality of the numerical variables visually

# %% [markdown]
# ### Use seaborn library to construct distribution plots for the numerical variables

# %%
sns.pairplot(numerical)

# %%
n_rows=3
n_cols=3
# Create the subplots
fig, axes = plt.subplots(nrows=n_rows, ncols=n_cols)
for i, column in enumerate(numerical.columns):
    sns.histplot(numerical[column],ax=axes[i//n_cols,i%n_cols])
axes[2,2].set_axis_off()

# %% [markdown]
# ### Use Matplotlib to construct histograms

# %%
mca.hist() # pandas
# Out:
# array([[<AxesSubplot:title={'center':'customer_lifetime_value'}>,
#         <AxesSubplot:title={'center':'effective_to_date'}>,
#         <AxesSubplot:title={'center':'income'}>],
#        [<AxesSubplot:title={'center':'monthly_premium_auto'}>,
#         <AxesSubplot:title={'center':'months_since_last_claim'}>,
#         <AxesSubplot:title={'center':'months_since_policy_inception'}>],
#        [<AxesSubplot:title={'center':'number_of_open_complaints'}>,
#         <AxesSubplot:title={'center':'number_of_policies'}>,
#         <AxesSubplot:title={'center':'total_claim_amount'}>],
#        [<AxesSubplot:title={'center':'month'}>, <AxesSubplot:>,
#         <AxesSubplot:>]], dtype=object)

# %% [markdown]
# ### Do the distributions for different numerical variables look like a normal distribution?

# %% [markdown]
# - No, the histograms from the different variables doesnt looks like they have a Gaussian distribution, so is not normally distributed.

# %% [markdown]
# ## For the numerical variables, check the multicollinearity between the features. Please note that we will use the column total_claim_amount later as the target variable.

# %%
corre_matrix=mca.corr()
corre_matrix
# Out:
#                                customer_lifetime_value    income  \
# customer_lifetime_value                       1.000000  0.028306
# income                                        0.028306  1.000000
# monthly_premium_auto                          0.403069 -0.009788
# months_since_last_claim                       0.015874 -0.022708
# months_since_policy_inception                 0.016960 -0.005903
# number_of_open_complaints                    -0.030616  0.008425
# number_of_policies                            0.016024 -0.009960
# total_claim_amount                            0.232626 -0.354141
# month                                        -0.009234 -0.000443
#
#                                monthly_premium_auto  months_since_last_claim  \
# customer_lifetime_value                    0.403069                 0.015874
# income                                    -0.009788                -0.022708
# monthly_premium_auto                       1.000000                 0.008489
# ...

# %% [markdown]
# ## Drop one of the two features that show a high correlation between them (greater than 0.9). Write code for both the correlation matrix and for seaborn heatmap. If there is no pair of features that have a high correlation, then do not drop any features

# %%
mask=np.zeros_like(corre_matrix)
mask[np.triu_indices_from(mask)]=True
fig,ax = plt.subplots(figsize=(10,8))
ax=sns.heatmap(corre_matrix, mask=mask, center=0, cmap=sns.diverging_palette(220, 20, as_cmap=True), annot=True,);

# %% [markdown]
# - We dont drop any of the features cause theres no correlation greater than 0.9.
