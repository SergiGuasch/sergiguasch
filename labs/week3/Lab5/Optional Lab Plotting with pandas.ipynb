# %% [markdown]
# # Challenge 1: Plot Precipitation Data

# %%
# Import Packages
import os

import matplotlib.pyplot as plt
import matplotlib.dates as mdates
import seaborn as sns
import pandas as pd
#import earthpy as et

# Add seaborn general plot specifications
sns.set(font_scale=1.5, style="whitegrid")

# %%
ls
# Out:
#  Volume in drive C is OS
#  Volume Serial Number is A4B9-8E3D
#
#  Directory of C:\Users\Sergi\OneDrive\Documents\GitHub\sergiguasch\labs\week3\Lab5
#
# 02/08/2022  01:10 PM    <DIR>          .
# 02/08/2022  01:07 PM    <DIR>          ..
# 02/04/2022  04:00 PM    <DIR>          .ipynb_checkpoints
# 02/04/2022  03:43 PM               210 avg-precip-months-seasons.csv
# 02/07/2022  10:54 AM            41,440 Lab Interacting with SQL from Python.ipynb
# 02/04/2022  07:15 PM             1,024 Lab Interacting with SQL from Python.sql
# 02/08/2022  01:10 PM           324,361 Optional Lab Plotting with pandas.ipynb
#                4 File(s)        367,035 bytes
#                3 Dir(s)  340,163,620,864 bytes free

# %%
data=pd.read_csv('avg-precip-months-seasons.csv')
data
# Out:
#    months  precip seasons
# 0     Jan    0.70  Winter
# 1     Feb    0.75  Winter
# 2     Mar    1.85  Spring
# 3     Apr    2.93  Spring
# 4     May    3.05  Spring
# 5    June    2.02  Summer
# 6    July    1.93  Summer
# 7     Aug    1.62  Summer
# 8    Sept    1.84    Fall
# 9     Oct    1.31    Fall
# 10    Nov    1.39    Fall
# 11    Dec    0.84  Winter

# %%
ax1=data.plot(lw=2, color='g', linestyle = ':', marker='.', markersize=20, legend=False, figsize=(15,15))
plt.title("Plot Challenge 1 \nAverage Precipitation")
plt.xlabel("Month")
plt.ylabel("Mean Precipitation (inches)")
default_x_ticks = range(len(data['months']))
plt.xticks(default_x_ticks, data['months'])
plt.show()

# %% [markdown]
# # Challenge 2: Bar Plot of Precipitation Data

# %%
ax2=data.plot.bar(color='g', edgecolor='black', width=0.8, rot=0, legend=False, figsize=(15,15))
plt.title("Plot Challenge 2 \nAverage Precipitation")
plt.xlabel("Month")
plt.ylabel("Mean Precipitation (inches)")
default_x_ticks = range(len(data['months']))
plt.xticks(default_x_ticks, data['months'])
plt.show()

# %% [markdown]
# # Challenge 3: Figure with Two Subplots of Precipitation Data

# %%
fig, (ax1, ax2) = plt.subplots(2,1, figsize=(15, 20))
plt.suptitle("Challenge 3. Overall Figure Title Using the Suptitle Method")

ax1.plot(data['months'], data['precip'], lw=2, color='g', linestyle = ':', marker='.', markersize=20)
ax1.set(title="Line Plot Challenge 1 \nAverage Precipitation", xlabel ="Month", ylabel="Mean Precipitation (inches)")
        
ax2.bar(data['months'], data['precip'], color='g', edgecolor='black', width=0.8)
ax2.set(title="Bar Plot Challenge 2 \nAverage Precipitation", xlabel ="Month", ylabel="Mean Precipitation (inches)")
        
plt.tight_layout()
plt.show()

# %% [markdown]
# # Bonus Challenge 4: Plot Grouped Data

# %%
colors = {"Winter": "lightgrey",
          "Spring": "green",
          "Summer": "darkgreen",
          "Fall": "brown"}

for label, df in data.groupby("seasons"):
    ax1.plot(data['months'], data['precip'],
            "o",
            label=label,
            color=colors[label])

# %%
for label, df in data.groupby("seasons"):
    print(label)

# %%
for label, df in data.groupby("seasons"):
    print(df)

# %%
from matplotlib.pyplot import figure

figure(num=None, figsize=(15, 15), dpi=100, facecolor='w', edgecolor='k')

plt.scatter(x=data['months'], y=data['precip'], color=colors[label], alpha=1)
plt.legend(colors)
plt.title("BONUS Challenge 4. Scatter Plot Colored by Season \nAverage Precipitation")
plt.xlabel("Month")
plt.ylabel("Mean Precipitation (inches)")
default_x_ticks = range(len(data['months']))
plt.xticks(default_x_ticks, data['months'])
plt.show()
