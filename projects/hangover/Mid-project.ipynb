# %%
import pandas as pd
import numpy as np

# %%
df2=pd.read_excel('regression_data.xls')
pd.get_option("display.max_columns", None)
df2
# Out:
#                id       date  bedrooms  bathrooms  sqft_living  sqft_lot  \
# 0      7129300520 2014-10-13         3       1.00         1180      5650
# 1      6414100192 2014-12-09         3       2.25         2570      7242
# 2      5631500400 2015-02-25         2       1.00          770     10000
# 3      2487200875 2014-12-09         4       3.00         1960      5000
# 4      1954400510 2015-02-18         3       2.00         1680      8080
# ...           ...        ...       ...        ...          ...       ...
# 21592   263000018 2014-05-21         3       2.50         1530      1131
# 21593  6600060120 2015-02-23         4       2.50         2310      5813
# 21594  1523300141 2014-06-23         2       0.75         1020      1350
# 21595   291310100 2015-01-16         3       2.50         1600      2388
# 21596  1523300157 2014-10-15         2       0.75         1020      1076
#
#        floors  waterfront  view  condition  ...  sqft_above  sqft_basement  \
# ...

# %%
df2.head()
# Out:
#            id       date  bedrooms  bathrooms  sqft_living  sqft_lot  floors  \
# 0  7129300520 2014-10-13         3       1.00         1180      5650     1.0
# 1  6414100192 2014-12-09         3       2.25         2570      7242     2.0
# 2  5631500400 2015-02-25         2       1.00          770     10000     1.0
# 3  2487200875 2014-12-09         4       3.00         1960      5000     1.0
# 4  1954400510 2015-02-18         3       2.00         1680      8080     1.0
#
#    waterfront  view  condition  ...  sqft_above  sqft_basement  yr_built  \
# 0           0     0          3  ...        1180              0      1955
# 1           0     0          3  ...        2170            400      1951
# 2           0     0          3  ...         770              0      1933
# 3           0     0          5  ...        1050            910      1965
# 4           0     0          3  ...        1680              0      1987
#
# ...

# %%
df2.describe()
# Out:
#                  id      bedrooms     bathrooms   sqft_living      sqft_lot  \
# count  2.159700e+04  21597.000000  21597.000000  21597.000000  2.159700e+04
# mean   4.580474e+09      3.373200      2.115826   2080.321850  1.509941e+04
# std    2.876736e+09      0.926299      0.768984    918.106125  4.141264e+04
# min    1.000102e+06      1.000000      0.500000    370.000000  5.200000e+02
# 25%    2.123049e+09      3.000000      1.750000   1430.000000  5.040000e+03
# 50%    3.904930e+09      3.000000      2.250000   1910.000000  7.618000e+03
# 75%    7.308900e+09      4.000000      2.500000   2550.000000  1.068500e+04
# max    9.900000e+09     33.000000      8.000000  13540.000000  1.651359e+06
#
#              floors    waterfront          view     condition         grade  \
# count  21597.000000  21597.000000  21597.000000  21597.000000  21597.000000
# mean       1.494096      0.007547      0.234292      3.409825      7.657915
# ...

# %%
df2.isnull().sum()
# Out:
# id               0
# date             0
# bedrooms         0
# bathrooms        0
# sqft_living      0
# sqft_lot         0
# floors           0
# waterfront       0
# view             0
# condition        0
# grade            0
# sqft_above       0
# sqft_basement    0
# yr_built         0
# yr_renovated     0
# zipcode          0
# lat              0
# long             0
# sqft_living15    0
# sqft_lot15       0
# price            0
# dtype: int64

# %%
df2.notnull().sum()
# Out:
# id               21597
# date             21597
# bedrooms         21597
# bathrooms        21597
# sqft_living      21597
# sqft_lot         21597
# floors           21597
# waterfront       21597
# view             21597
# condition        21597
# grade            21597
# sqft_above       21597
# sqft_basement    21597
# yr_built         21597
# yr_renovated     21597
# zipcode          21597
# lat              21597
# long             21597
# sqft_living15    21597
# sqft_lot15       21597
# price            21597
# dtype: int64

# %%
df2.id.duplicated().sum() #checking howmany duplicated through ids they are
# Out:
# 177

# %%
df2.duplicated().sum() #checking if there are duplicated rows.
# Out:
# 0

# %%
df2.loc[df2.id.duplicated(),:]
# Out:
#                id       date  bedrooms  bathrooms  sqft_living  sqft_lot  \
# 94     6021501535 2014-12-23         3       1.50         1580      5000
# 314    4139480200 2014-12-09         4       3.25         4290     12103
# 325    7520000520 2015-03-11         2       1.00         1240     12092
# 346    3969300030 2014-12-29         4       1.00         1000      7134
# 372    2231500030 2015-03-24         4       2.25         2180     10754
# ...           ...        ...       ...        ...          ...       ...
# 20165  7853400250 2015-02-19         4       3.50         2910      5260
# 20597  2724049222 2014-12-01         2       2.50         1000      1092
# 20654  8564860270 2015-03-30         4       2.50         2680      5539
# 20764  6300000226 2015-05-04         4       1.00         1200      2171
# 21565  7853420110 2015-05-04         3       3.00         2780      6000
#
#        floors  waterfront  view  condition  ...  sqft_above  sqft_basement  \
# ...

# %%
pd.get_option("display.max_columns", None)
# Out:
# 20

# %%
df2.loc[df2['id']==7853400250]
# Out:
#                id       date  bedrooms  bathrooms  sqft_living  sqft_lot  \
# 20164  7853400250 2014-06-04         4        3.5         2910      5260
# 20165  7853400250 2015-02-19         4        3.5         2910      5260
#
#        floors  waterfront  view  condition  ...  sqft_above  sqft_basement  \
# 20164     2.0           0     0          3  ...        2910              0
# 20165     2.0           0     0          3  ...        2910              0
#
#        yr_built  yr_renovated  zipcode      lat     long  sqft_living15  \
# 20164      2012             0    98065  47.5168 -121.883           2910
# 20165      2012             0    98065  47.5168 -121.883           2910
#
#        sqft_lot15   price
# 20164        5260  610000
# 20165        5260  645000
#
# [2 rows x 21 columns]

# %%
df2.dtypes
# Out:
# id                        int64
# date             datetime64[ns]
# bedrooms                  int64
# bathrooms               float64
# sqft_living               int64
# sqft_lot                  int64
# floors                  float64
# waterfront                int64
# view                      int64
# condition                 int64
# grade                     int64
# sqft_above                int64
# sqft_basement             int64
# yr_built                  int64
# yr_renovated              int64
# zipcode                   int64
# lat                     float64
# long                    float64
# sqft_living15             int64
# sqft_lot15                int64
# price                     int64
# dtype: object

# %%
df2.sort_values('date')
# Out:
#                id       date  bedrooms  bathrooms  sqft_living  sqft_lot  \
# 7316   2202500290 2014-05-02         4       1.00         1450      8800
# 20586  7853361370 2014-05-02         4       2.50         3310      6500
# 1040   7197300105 2014-05-02         4       2.50         1940     10500
# 20543  3438501320 2014-05-02         2       2.50         1630      1368
# 9587    472000620 2014-05-02         3       2.50         2600      4750
# ...           ...        ...       ...        ...          ...       ...
# 19381  8149600265 2015-05-14         4       1.75         1980      5850
# 12623  4166600610 2015-05-14         3       2.00         1410     44866
# 5632   7923600250 2015-05-15         5       2.00         1870      7344
# 13040  5101400871 2015-05-24         2       1.75         1390      6670
# 16580  9106000005 2015-05-27         4       2.25         3750      5000
#
#        floors  waterfront  view  condition  ...  sqft_above  sqft_basement  \
# ...
