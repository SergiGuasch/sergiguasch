# %% [markdown]
# <h1>Index<span class="tocSkip"></span></h1>
# <div class="toc"><ul class="toc-item"><li><span><a href="#Spotify-Developer-Account" data-toc-modified-id="Spotify-Developer-Account-1"><span class="toc-item-num">1&nbsp;&nbsp;</span>Spotify Developer Account</a></span><ul class="toc-item"><li><span><a href="#Log-in-or-your-user-account" data-toc-modified-id="Log-in-or-your-user-account-1.1"><span class="toc-item-num">1.1&nbsp;&nbsp;</span>Log in or your user account</a></span></li><li><span><a href="#Create-an-App" data-toc-modified-id="Create-an-App-1.2"><span class="toc-item-num">1.2&nbsp;&nbsp;</span>Create an App</a></span></li><li><span><a href="#Client-ID-and-Client-Secret" data-toc-modified-id="Client-ID-and-Client-Secret-1.3"><span class="toc-item-num">1.3&nbsp;&nbsp;</span>Client ID and Client Secret</a></span></li></ul></li><li><span><a href="#Connect-with-Jupyter-Notebook" data-toc-modified-id="Connect-with-Jupyter-Notebook-2"><span class="toc-item-num">2&nbsp;&nbsp;</span>Connect with Jupyter Notebook</a></span><ul class="toc-item"><li><span><a href="#Step-1:-Install-Spotipy" data-toc-modified-id="Step-1:-Install-Spotipy-2.1"><span class="toc-item-num">2.1&nbsp;&nbsp;</span>Step 1: Install Spotipy</a></span></li></ul></li><li><span><a href="#Connect-to-a-play-list" data-toc-modified-id="Connect-to-a-play-list-3"><span class="toc-item-num">3&nbsp;&nbsp;</span>Connect to a play list</a></span></li><li><span><a href="#sp-search-on-one-artist-and-explore-results" data-toc-modified-id="sp-search-on-one-artist-and-explore-results-4"><span class="toc-item-num">4&nbsp;&nbsp;</span>sp search on one artist and explore results</a></span></li><li><span><a href="#8.05-Activity-1" data-toc-modified-id="8.05-Activity-1-5"><span class="toc-item-num">5&nbsp;&nbsp;</span>8.05 Activity 1</a></span></li><li><span><a href="#Create-a-function-to-extract-all-the-artists-of-a-song-and-another-function-to-extract-all-the-artists-IDs-from-a-song." data-toc-modified-id="Create-a-function-to-extract-all-the-artists-of-a-song-and-another-function-to-extract-all-the-artists-IDs-from-a-song.-6"><span class="toc-item-num">6&nbsp;&nbsp;</span>Create a function to extract all the artists of a song and another function to extract all the artists IDs from a song.</a></span></li></ul></div>

# %% [markdown]
# # Connecting Python to Spotify with Spotipy

# %% [markdown]
# ## Spotify Developer Account

# %% [markdown]
# ### Log in or your user account

# %% [markdown]
# Go to [Spotify for Developers](https://developer.spotify.com/dashboard/) and log in.

# %% [markdown]
# <img src="developers_log_in_2.png">

# %% [markdown]
# ### Create an App

# %% [markdown]
# You will need to accept the _Spotify Developer Terms of Service_, sorry. Next you will see **your Dashboard** and it is probably empty so let's create an app.

# %% [markdown]
# <img src="dashboard_1.png">

# %% [markdown]
# Choose a name for your app (whatever you want). This is just the name of the space for the API to follow your activity for this 'scraping' project. You can create more than one or use always the same.

# %% [markdown]
# <img src="dashboard_app.png">

# %% [markdown]
# ### Client ID and Client Secret

# %% [markdown]
# Credentials:
# - Client ID
# - Client Secret (click on top to see the 'password', keep it safe)

# %% [markdown]
# <img src="dashboard_app_inside.png">

# %% [markdown]
# ## Connect with Jupyter Notebook

# %% [markdown]
# ### Step 1: Install Spotipy
#
# Run the code below in your terminal or a Jupyter Notebook to install Spotipy.
#
# `!pip install spotipy`
#
# `conda install -c conda-forge spotipy`

# %%
import spotipy # install if needed
from spotipy.oauth2 import SpotifyClientCredentials
import getpass

# %%
client_id = str(getpass.getpass('client_id?'))
client_secret = str(getpass.getpass('client_secret?'))
# Out:
# client_id?········
# client_secret?········

# %%
client_credentials_manager = SpotifyClientCredentials(client_id, client_secret)
sp = spotipy.Spotify(client_credentials_manager = client_credentials_manager)

# %% [markdown]
# ## Connect to a play list

# %%
playlist = sp.user_playlist_tracks('Starred','10ZqprIeFYbYgGolvxTsmH')

# %%
playlist

# %%
playlist.keys()
# Out:
# dict_keys(['href', 'items', 'limit', 'next', 'offset', 'previous', 'total'])

# %%
playlist['items'][3].keys()
# Out:
# dict_keys(['added_at', 'added_by', 'is_local', 'primary_color', 'track', 'video_thumbnail'])

# %%
playlist['items'][3]['track'].keys()
# Out:
# dict_keys(['album', 'artists', 'available_markets', 'disc_number', 'duration_ms', 'episode', 'explicit', 'external_ids', 'external_urls', 'href', 'id', 'is_local', 'name', 'popularity', 'preview_url', 'track', 'track_number', 'type', 'uri'])

# %%
playlist['items'][3]['track']['name']
# Out:
# 'Paper Aeroplane'

# %% [markdown]
# ## sp search on one artist and explore results

# %%
results_artist=sp.search(q='Miles Davis', limit=50)

# %%
results_artist

# %%
results_artist['tracks']['items'][0]['name']
# Out:
# 'Blue in Green (feat. John Coltrane & Bill Evans)'

# %%
results_artist['tracks']['items'][49]['external_urls']
# Out:
# {'spotify': 'https://open.spotify.com/track/6xdpwECaUdzv48eP9W9Urj'}

# %%
results_artist['tracks']['items'][0]['album']['release_date']
# Out:
# '1959-08-17'

# %%
results_artist['tracks']['items'][0]['album']['total_tracks']
# Out:
# 21

# %%
results_artist['tracks']['items'][0]['artists'][0].keys()
# Out:
# dict_keys(['external_urls', 'href', 'id', 'name', 'type', 'uri'])

# %%
results_artist['tracks']['items'][0]['artists'][0]['name']
# Out:
# 'Miles Davis'

# %% [markdown]
# ## 8.05 Activity 1

# %% [markdown]
# - Create a list and assign it to a variable named my_20_artists.

# %%
artists=['Louis Armstrong', 'Miles Davis', 'Ella Fitzgerald', 'Billie Holliday',
         'Nina Simone', 'Etta James', 'Jimi Hendrix', 'Howlin Wolf', 'Muddy Waters']
# note there are 9 artists in my list

# %%
my_artists_tracks = []
for artist in artists:
    my_artists_tracks.append(sp.search(q=artist,type='track',market='GB',limit=50))

# %%
len(my_artists_tracks)
# Out:
# 9

# %%
import pprint

# %%
pprint.pprint(my_artists_tracks)

# %%
my_artists_tracks[8]['tracks']['items'][49]['name']
# Out:
# "I Can't Be Satisfied"

# %%
def artist_to_dict(artists):
    return {artist:sp.search(q=artist,type='track',market='GB',limit=50) for artist in artists}

# %%
len(artist_to_dict(artists))
# Out:
# 9

# %%
mydict=artist_to_dict(artists)

# %%
mydict.get('Jimi Hendrix')['tracks']['items'][1]['name']
# Out:
# 'Are You Experienced - Live 10/11/68 Winterland, San Francisco, CA'

# %%
mydict

# %% [markdown]
# - Loop over your 20 favorite artists and their results to the list.

# %%
my_20_artists.keys()
# Out:
# dict_keys(['tracks'])

# %%
my_20_artists['items'][0].keys()
# Out:
# dict_keys(['added_at', 'added_by', 'is_local', 'primary_color', 'track', 'video_thumbnail'])

# %% [markdown]
# - Create a function that takes a list of artist names and return their 50 first appearances as a dictionary.

# %% [markdown]
# # 8.05 Activity 2

# %% [markdown]
# ## Create a function to extract all the artists of a song and another function to extract all the artists IDs from a song.
#
# - Input: track dictionary
# - Output: List of artists/List of IDs

# %%
def get_artists_from_track (track):
    return [artist['name'] for artist in track['artists']]

# %%
results_artist['tracks']['items'][0]['artists'][0].keys()
# Out:
# dict_keys(['external_urls', 'href', 'id', 'name', 'type', 'uri'])

# %%
get_artists_from_track(results_artist['tracks']['items'][0])
# Out:
# ['Miles Davis', 'John Coltrane', 'Bill Evans']

# %%
def get_artists_id_from_track (track):
    return [artist['id'] for artist in track['artists']]

# %%
get_artists_id_from_track(results_artist['tracks']['items'][0])
# Out:
# ['0kbYTNQb4Pb1rPbbaF0pT4', '2hGh5VOeeqimQFxqXvfCUf', '4jXfFzeP66Zy67HM2mvIIF']

# %% [markdown]
# # Playlist

# %%
# limited playlist - 10 songs
# bigger playlist - more than 100 songs>

# %% [markdown]
# https://open.spotify.com/playlist/0qvjU54K8T1wdzZR1fguzG?si=f189f32da19d4060
#     useful info: 0qvjU54K8T1wdzZR1fguzG
#         playlist owner - yellowno55

# %%
# user playlist_tracks

# %%
playlist=sp.user_playlist_tracks('yellowno55','0qvjU54K8T1wdzZR1fguzG')

# %%
playlist
# Out:
# {'href': 'https://api.spotify.com/v1/playlists/0qvjU54K8T1wdzZR1fguzG/tracks?offset=0&limit=100&additional_types=track',
#  'items': [{'added_at': '2021-05-25T18:56:02Z',
#    'added_by': {'external_urls': {'spotify': 'https://open.spotify.com/user/jhgyvlkdvkc9wfdpaniidsl32'},
#     'href': 'https://api.spotify.com/v1/users/jhgyvlkdvkc9wfdpaniidsl32',
#     'id': 'jhgyvlkdvkc9wfdpaniidsl32',
#     'type': 'user',
#     'uri': 'spotify:user:jhgyvlkdvkc9wfdpaniidsl32'},
#    'is_local': False,
#    'primary_color': None,
#    'track': {'album': {'album_type': 'album',
#      'artists': [{'external_urls': {'spotify': 'https://open.spotify.com/artist/6X8lhZ7YaRUBlOsOYimlyD'},
#        'href': 'https://api.spotify.com/v1/artists/6X8lhZ7YaRUBlOsOYimlyD',
#        'id': '6X8lhZ7YaRUBlOsOYimlyD',
#        'name': 'Kiasmos',
#        'type': 'artist',
#        'uri': 'spotify:artist:6X8lhZ7YaRUBlOsOYimlyD'}],
#      'available_markets': ['AD',
#       'AE',
#       'AG',
#       'AL',
# ...

# %%
playlist.keys()
# Out:
# dict_keys(['href', 'items', 'limit', 'next', 'offset', 'previous', 'total'])

# %%
playlist['total']
# Out:
# 23

# %%
playlist_big=sp.user_playlist_tracks('PMB Music','69tUdeFaKRDVTg2guSDttx')

# %%
playlist_big.keys()
# Out:
# dict_keys(['href', 'items', 'limit', 'next', 'offset', 'previous', 'total'])

# %%
playlist_big['total']
# Out:
# 1038

# %%
len(playlist_big['items'])
# Out:
# 100

# %%
playlist_big['next']
# Out:
# 'https://api.spotify.com/v1/playlists/69tUdeFaKRDVTg2guSDttx/tracks?offset=100&limit=100&additional_types=track'

# %%
playlist_big['offset']
# Out:
# 0

# %%
playlist_big['previous']

# %%
# 5th track in the playlist
playlist_big['items'][4]['track']['name']
# Out:
# 'High & Dry'

# %% [markdown]
# # 8.05 Activity 3

# %% [markdown]
# - Iterate over the call (playlist) first 100 tracks to get all the songs ID, name, and artists.
#
# - Output: Dictionary with key: song ID and values: list(song name, artist).

# %%
my_tracks = {}

for i in range(len(playlist_big['items'])):
    my_tracks[str(playlist_big['items'][i]['track']['id'])]=(str(playlist_big['items'][i]['track']['name'])),(str(playlist_big['items'][i]['track']['artists'][0]['name']))
my_tracks
# Out:
# {'7pSzRRMaPXA39wvrnvdmSH': ('Original Sin', 'INXS'),
#  '07zkNvtcmPOFlMOXbma13k': ('Sussudio', 'Phil Collins'),
#  '603aPXFY2Ec2WuFganUGuD': ("Don't You (Forget About Me)", 'Simple Minds'),
#  '6i8ecOsx4J2Px1maiqzqoG': ('Everywhere', 'Fleetwood Mac'),
#  '7oWqXVRExRlNR0jZJNoO9w': ('High & Dry', 'ABC'),
#  '3Dmm864eNf511Pn6uwvTa6': ('Everybody Wants To Rule The World',
#   'Tears For Fears'),
#  '6aLWY1Lax3ASlHzNAl2xRZ': ('Billie Jean - Single Version', 'Michael Jackson'),
#  '34J7wKxw1bbbqilKZFHHGG': ('Have You Ever Seen the Rain', 'Belinda Carlisle'),
#  '2PnNomkEqlg9ADKCVG0Wt0': ('Every Breath You Take', 'The Police'),
#  '3oQ2qU2IFxL1Qp4pXQrYte': ('Smooth Operator - Single Version', 'Sade'),
#  '1LFK84nUerBbYfFd1LmnTm': ('A Kind Of Magic - Remastered 2011', 'Queen'),
#  '61HGj25ENxWMuSYibZfqyM': ('Square Rooms', 'Al Corley'),
#  '0BeaqEnmbH6NTnede0s6Jo': ('Cars and Girls', 'Prefab Sprout'),
#  '3VXKs6WzxkwdXtVYkmhk9Q': ('Under My Thumb', 'Kim Carnes'),
# ...

# %%
songs={}

# %% [markdown]
# # Audio features

# %%
# get track list with url, uri or ID for each track
# run audio-features query
# if there's no features use try except fill with 0

# %%
import pandas as pd

# %%
spaceplaylist=[]
for i in playlist['items']:
    spaceplaylist.append(i['track']['id'])

# %%
spaceplaylist
# Out:
# ['7o9YZMRDgPQj48PwdT72wF',
#  '0jJLwPDpyuZRpd800yScN0',
#  '1rHJ52s5MLNmYwLewMMnQp',
#  '5LT8fCP8IiaDV6oNL2r5w1',
#  '4uayzCHBoZ1cpTSpMmdMXB',
#  '72g08nB68PvptBYjH5m5HQ',
#  '3xVTbxVNTcy3P0eBXlAIUh',
#  '2RjVf6pGKM9d5pCW11YtcB',
#  '2bB6iDVgm25WkYv0yBz1BD',
#  '4YwVxBki1dhLsn7qN034AY',
#  '6xzpUzzIquIyUzTLbbgSdI',
#  '6lED9RL8keuWSCZdHMvfTP',
#  '4JD1CS0yfo9EXHOZbc0eKo',
#  '1Qg4Da7hw0JlpjLMWwVDU8',
#  '53k0rPq5qhzslsjB3XBdl8',
#  '2EwG3eXgncPRkQMyiuJeKr',
#  '2xbJaVQRJLmf42DrUdTqDq',
#  '54S7IAZlP3fftrIoQfybJw',
#  '308ht8jmkm9XE1Hh0aotnI',
#  '1feN3rsdibC2lBkL8zHvyP',
#  '2qhsbKgNyHS1d9GQWr4s1y',
#  '1mAVJMb2nREYO0Kt34263f',
#  '0PQ5ZcmRmLVwQ7JEyY2WW4']

# %%
audio_feat_space=pd.DataFrame(sp.audio_features(tracks=spaceplaylist))

# %%
audio_feat_space
# Out:
#     danceability  energy  key  loudness  mode  speechiness  acousticness  \
# 0          0.702   0.557    0   -12.046     1       0.0406       0.40700
# 1          0.853   0.406    4   -11.658     1       0.0483       0.58700
# 2          0.707   0.826    0   -12.101     0       0.0401       0.68200
# 3          0.698   0.476   11   -18.209     0       0.0486       0.48900
# 4          0.678   0.629    1   -13.102     0       0.0442       0.05770
# 5          0.644   0.645    2   -13.614     1       0.0410       0.05710
# 6          0.601   0.206    3   -17.611     1       0.0375       0.08530
# 7          0.652   0.297    7   -13.349     0       0.0289       0.51200
# 8          0.804   0.406    7   -11.154     0       0.0472       0.02300
# 9          0.810   0.556   11   -12.571     0       0.0664       0.15600
# 10         0.750   0.340    5   -12.759     0       0.0326       0.16700
# 11         0.687   0.597    5   -11.643     0       0.0910       0.25300
# ...

# %%
audio_feat_space.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 23 entries, 0 to 22
# Data columns (total 18 columns):
#  #   Column            Non-Null Count  Dtype
# ---  ------            --------------  -----
#  0   danceability      23 non-null     float64
#  1   energy            23 non-null     float64
#  2   key               23 non-null     int64
#  3   loudness          23 non-null     float64
#  4   mode              23 non-null     int64
#  5   speechiness       23 non-null     float64
#  6   acousticness      23 non-null     float64
#  7   instrumentalness  23 non-null     float64
#  8   liveness          23 non-null     float64
#  9   valence           23 non-null     float64
#  10  tempo             23 non-null     float64
#  11  type              23 non-null     object
#  12  id                23 non-null     object
#  13  uri               23 non-null     object
#  14  track_href        23 non-null     object
#  15  analysis_url      23 non-null     object
# ...
